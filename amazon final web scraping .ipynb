# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':
    
    # add your user agent 
    HEADERS = ({'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'})
    
    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+5&crid=3BV45YDFQQE2G&sprefix=playstation+4%2Caps%2C269&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
    
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True) #replace empty value with null value
    amazon_df = amazon_df.dropna(subset=['title'])        #drop null values if we don't find title
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df

# %%
# print(amazon_df)
# Out:
#                                                 title price
# 0   PlayStation PS5 Console – God of War Ragnarök ...        \
# 1                  PlayStation 5 Console CFI-1215A01X
# 2                     PlayStation 5 Console (Renewed)
# 3                     PlayStation 5 Console CFI-1102A
# 4             PlayStation 5 Pulse 3D Wireless Headset
# 5                       PlayStation 5 Digital Edition
# 6           PlayStation 5 Digital Edition - CFI-1102B
# 7   PlayStation DualSense Wireless Controller - St...
# 8   WD_BLACK 2TB SN850 NVMe SSD for PS5 Consoles S...
# 9    PlayStation 5 Console – FINAL FANTASY XVI Bundle
# 10  PlayStation 4 Slim 500GB Console [Discontinued...
# 11   PlayStation 4 Slim 1TB Console - Black (Renewed)
# 12       Sony PlayStation 2 Console - Black (Renewed)
# 13  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 14           PlayStation 2 Slim Console PS2 (Renewed)
# 15  Playstation SONY 4, 500GB Slim System [CUH-221...
# 16            Playstation 2 Console - Black (Renewed)
# 17  PlayStation 4 Slim 1TB Console - Marvels Spide...
# 18             Xbox Series X – Forza Horizon 5 Bundle
# 19                 Sonic Origins Plus - PlayStation 5
# 20                 DualSense Edge Wireless Controller
# 21                         Tchia: Oléti Edition (PS5)
# 22    Star Wars Jedi: Survivor Deluxe - PlayStation 5
# 23  Roblox Digital Gift Card - 800 Robux [Includes...
# 24  Heiko PS5 Faceplates for Playstation 5 Console...
# 25   Minecraft Legends - Deluxe Edition PlayStation 5
# 26  SKULL AND BONES – PlayStation 5, Standard Edition
# 27  G-STORY 15.6" Inch IPS 4k 60Hz Portable Monito...
# 28  Opcables Fiber Optic HDMI 2.1 Cable High-Speed...
#
#                                          rating          reviews
# 0                            4.8 out of 5 stars    8,455 ratings  \
# 1                            4.8 out of 5 stars    3,206 ratings
# 2                            3.4 out of 5 stars        5 ratings
# 3                            4.9 out of 5 stars    7,295 ratings
# 4                            4.7 out of 5 stars   19,519 ratings
# 5                            4.9 out of 5 stars    7,200 ratings
# 6                            4.9 out of 5 stars      707 ratings
# 7                            4.8 out of 5 stars   73,834 ratings
# 8                            4.8 out of 5 stars    2,785 ratings
# 9   Previous page of related Sponsored Products
# 10                           4.5 out of 5 stars    1,273 ratings
# 11                           4.4 out of 5 stars    1,249 ratings
# 12                           4.3 out of 5 stars    1,168 ratings
# 13                           4.2 out of 5 stars    1,086 ratings
# 14                           4.2 out of 5 stars      978 ratings
# 15                           4.7 out of 5 stars      347 ratings
# 16                           4.2 out of 5 stars      316 ratings
# 17                           4.4 out of 5 stars      308 ratings
# 18                           4.7 out of 5 stars      423 ratings
# 19  Previous page of related Sponsored Products
# 20                           4.8 out of 5 stars   73,834 ratings
# 21  Previous page of related Sponsored Products
# 22                           4.1 out of 5 stars       25 ratings
# 23                           4.5 out of 5 stars  138,054 ratings
# 24                           4.7 out of 5 stars       31 ratings
# 25                           5.0 out of 5 stars         1 rating
# 26  Previous page of related Sponsored Products
# 27                           4.5 out of 5 stars      281 ratings
# 28                           4.7 out of 5 stars       14 ratings
#
#                                        availability
# 0                                          In Stock
# 1                                          In Stock
# 2                            Currently unavailable.
# 3                                          In Stock
# 4                                     Not Available
# 5
# 6
# 7                                     Not Available
# 8                                          In Stock
# 9      This item will be released on June 22, 2023.
# 10                                    Not Available
# 11                                    Not Available
# 12                                    Not Available
# 13                                    Not Available
# 14                                    Not Available
# 15                                    Not Available
# 16                                    Not Available
# 17                                    Not Available
# 18                Only 1 left in stock - order soon
# 19     This item will be released on June 23, 2023.
# 20                                         In Stock
# 21     This item will be released on July 18, 2023.
# 22                                         In Stock
# 23                                    Available now
# 24                                    Not Available
# 25                                         In Stock
# 26  This item will be released on December 1, 2023.
# 27                                         In Stock
# 28                                         In Stock
